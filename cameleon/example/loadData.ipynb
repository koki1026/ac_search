# %%
#pklをロードし、printする
import pickle
import sys
import os
import numpy as np
import matplotlib.pyplot as plt
import torch


pkl_file = '../cameleon_ros_ws/rollout.pkl'
with open(pkl_file, 'rb') as f:
    data = pickle.load(f)
print(data)
print(type(data.obs))
# Out:
# TransitionsMinimal(obs=array([[1., 1., 2., 1., 2., 2., 3., 3.],
#        [1., 1., 2., 1., 2., 2., 3., 3.],
#        [1., 1., 2., 1., 2., 2., 3., 3.],
#        [1., 1., 2., 1., 2., 2., 3., 3.],
#        [1., 1., 2., 1., 2., 2., 3., 3.],
#        [1., 1., 2., 1., 2., 2., 3., 3.],
#        [1., 1., 2., 1., 2., 2., 3., 3.],
#        [1., 1., 2., 1., 2., 2., 3., 3.],
#        [1., 1., 2., 1., 2., 2., 3., 3.],
#        [1., 1., 2., 1., 2., 2., 3., 3.],
#        [1., 1., 2., 1., 2., 2., 3., 3.],
#        [1., 1., 2., 1., 2., 2., 3., 3.],
#        [1., 1., 2., 1., 2., 2., 3., 3.],
#        [1., 1., 2., 1., 2., 2., 3., 3.],
#        [1., 1., 2., 1., 2., 2., 3., 3.],
#        [1., 1., 2., 1., 2., 2., 3., 3.],
#        [1., 1., 2., 1., 2., 2., 3., 3.],
#        [1., 1., 2., 1., 2., 2., 3., 3.],
#        [1., 1., 2., 1., 2., 2., 3., 3.],
#        [1., 1., 2., 1., 2., 2., 3., 3.],
#        [1., 1., 2., 1., 2., 2., 3., 3.],
#        [1., 1., 2., 1., 2., 2., 3., 3.],
# ...
